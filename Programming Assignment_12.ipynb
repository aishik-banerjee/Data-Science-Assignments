# %%
Write a Python program to Extract Unique values dictionary values?

# %%
test_dict = {'gfg' : [5, 6, 7, 8],
             'is' : [10, 11, 7, 5],
             'best' : [6, 12, 10, 8],
             'for' : [1, 2, 5]}
l=[]
for i in test_dict.values():
    l.extend(i)
unique=set(l)
print(unique)
# Out:
# {1, 2, 5, 6, 7, 8, 10, 11, 12}

# %%
Write a Python program to find the sum of all items in a dictionary?

# %%
test_dict = {'gfg' : [5, 6, 7, 8],
             'is' : [10, 11, 7, 5],
             'best' : [6, 12, 10, 8],
             'for' : [1, 2, 5]}
l=[]
for i in test_dict.values():
    l.extend(i)
print (sum(l))
# Out:
# 103

# %%
Write a Python program to Merging two Dictionaries?

# %%
test_dict1 = {'p1' : [5, 6, 7, 8],
             'p2' : [10, 11, 7, 5],
             'p3' : [6, 12, 10, 8],
             'p4' : [1, 2, 5]}

test_dict2 = {'p5' : [1, 2, 3, 4],
             'p6' : [5, 6, 7, 8],
             'p7' : [1, 5, 9],
             'p8' : [7, 5, 3]}

for i,j in test_dict2.items():
    test_dict1[i]=j
    
print (test_dict1)
# Out:
# {'p1': [5, 6, 7, 8], 'p2': [10, 11, 7, 5], 'p3': [6, 12, 10, 8], 'p4': [1, 2, 5], 'p5': [1, 2, 3, 4], 'p6': [5, 6, 7, 8], 'p7': [1, 5, 9], 'p8': [7, 5, 3]}

# %%
Write a Python program to convert key-values list to flat dictionary?

# %%
test_dict = {'month' : [1, 2, 3],
             'name' : ['Jan', 'Feb', 'March']}
  
print("The original dictionary is : " + str(test_dict))
res = dict(zip(test_dict['month'], test_dict['name']))
print("Flattened dictionary : " + str(res))
# Out:
# The original dictionary is : {'month': [1, 2, 3], 'name': ['Jan', 'Feb', 'March']}
# Flattened dictionary : {1: 'Jan', 2: 'Feb', 3: 'March'}

# %%
Write a Python program to insertion at the beginning in OrderedDict?

# %%
from collections import OrderedDict
_dict = OrderedDict([('akshat', '1'), ('nikhil', '2')])
_dict.update({'manjeet':'3'})
_dict.move_to_end('manjeet', last = False)
print ("Resultant Dictionary : "+str(_dict))
# Out:
# Resultant Dictionary : OrderedDict([('manjeet', '3'), ('akshat', '1'), ('nikhil', '2')])

# %%
Write a Python program to check order of character in string using OrderedDict()?

# %%
from collections import OrderedDict
def check_order(my_input, my_pattern):
   my_dict = OrderedDict.fromkeys(my_input)
   pattern_length = 0
   for key,value in my_dict.items():
      if (key == my_pattern[pattern_length]):
         pattern_length = pattern_length + 1

      if (pattern_length == (len(my_pattern))):
         return 'The order of pattern is correct'

   return 'The order of pattern is incorrect'

my_input = 'Hi Mark'
input_pattern = 'Ma'
print("The string is ")
print(my_input)
print("The input pattern is ")
print(input_pattern)
print(check_order(my_input,input_pattern))
# Out:
# The string is
# Hi Mark
# The input pattern is
# Ma
# The order of pattern is correct

# %%
Write a Python program to sort Python Dictionaries by Key or Value?

# %%
key_value ={}   
key_value[2] = 56      
key_value[1] = 2
key_value[5] = 12
key_value[4] = 24
key_value[6] = 18     
key_value[3] = 323
print ("Sorted by Keys")
for i in sorted (key_value.keys()) :
     print(i, key_value[i])
# Out:
# Sorted by Keys
# 1 2
# 2 56
# 3 323
# 4 24
# 5 12
# 6 18
