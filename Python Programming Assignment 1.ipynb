# %%
1.	Write a Python program to print "Hello Python"?

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
2.	Write a Python program to do arithmetical operations addition and division.?

# %%
a=int(input("Enter 1st number "))
b=int(input("Enter 2nd number "))
print("Addition: "+(str)(a+b)+ " Division: "+(str)(a//b))
# Out:
# Enter 1st number 10
# Enter 2nd number 2
# Addition: 12 Division: 5

# %%
3.	Write a Python program to find the area of a triangle?

# %%
a=float(input("Enter the 1st side "))
b=float(input("Enter the 2nd side "))
c=float(input("Enter the 3rd side "))
#Finding semi perimeter
s=(a+b+c)/2
#Herons formula
area=s*(s-a)*(s-b)*(s-c)**0.5
print(f"The area of triangle is {area}")
# Out:
# Enter the 1st side 3
# Enter the 2nd side 4
# Enter the 3rd side 5
# The area of triangle is 36.0

# %%
4.	Write a Python program to swap two variables?

# %%
a=int(input("Enter the 1st variable "))
b=int(input("Enter the 2nd variable "))
temp=0
print(f"BEFORE SWAPPING -----> a={a} and b={b}")
temp=a
a=b
b=temp
print(f"AFTER SWAPPING -----> a={a} and b={b}")
# Out:
# Enter the 1st variable 25
# Enter the 2nd variable 50
# BEFORE SWAPPING -----> a=25 and b=50
# AFTER SWAPPING -----> a=50 and b=25

# %%
5.	Write a Python program to generate a random number?

# %%
import random
l=int(input("Enter lower limit "))
h=int(input("Enter higher limit "))
r=random.randint(l,h)
print(r)
# Out:
# Enter lower limit 100
# Enter higher limit 1000
# 494
