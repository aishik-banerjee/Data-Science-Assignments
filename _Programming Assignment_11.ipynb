# %%
Write a Python program to find words which are greater than given length k?

# %%
s=input("Enter the string")
k=int(input("Enter the limit k"))
l=s.split(" ")
for i in range(len(l)):
    if(len(l[i])>k):
        print (l[i])
# Out:
# Enter the stringhello my name is aishik banerjee
# Enter the limit k4
# hello
# aishik
# banerjee

# %%
Write a Python program for removing i-th character from a string?

# %%
s=input("Enter the string ")
i=int(input("Enter the value of i "))
newString=s[:i-1]+s[i:]
print (newString)
# Out:
# Enter the string aishik
# Enter the value of i 3
# aihik

# %%
Write a Python program to split and join a string?

# %%
s=input("Enter the string ")
#Split
l=s.split(" ")
print (l)
#Join
print(" ".join(l))
# Out:
# Enter the string Aishik Banerjee is a good boy
# ['Aishik', 'Banerjee', 'is', 'a', 'good', 'boy']
# Aishik Banerjee is a good boy

# %%
Write a Python to check if a given string is binary string or not?

# %%
s=input("Enter the string ")
s1=set(s)
if (s1=={'0','1'} or s1=={'0'} or s1=={'1'}):
    print ("Binary String")
else:
    print ("Not a Binary String")
# Out:
# Enter the string 01011001
# Binary String

# %%
Write a Python program to find uncommon words from two Strings?

# %%
s1=input("Enter the string ")
s2=input("Enter the string ")
l1=s1.split(" ")
l2=s2.split(" ")
a=set(l1)
b=set(l2)
uncommon=a.symmetric_difference(b)
print (uncommon)
# Out:
# Enter the string my name is aishik
# Enter the string my name is rahul
# {'rahul', 'aishik'}

# %%
Write a Python to find all duplicate characters in string?

# %%
s=input("Enter the string ")
for i in range(len(s)):
    count=0
    for j in range(i+1,len(s)):
        if(s[i]==s[j]):
            count=count+1
    if (count > 0 ):
        print (s[i])
# Out:
# Enter the string abcdefghabc
# a
# b
# c

# %%
Write a Python Program to check if a string contains any special character?

# %%
s=input("Enter the string ")
print ("Special Characters")
for i in s:
    if ((ord(i) >= 32 and ord(i) <= 47) or (ord(i) >= 58 and ord(i) <= 64) or (ord(i) >= 91 and ord(i) <= 96) or (ord(i) >= 123 and ord(i) <= 126)):
        print (i)
# Out:
# Enter the string aishikbanerjee97@gmail.com
# Special Characters
# @
# .
